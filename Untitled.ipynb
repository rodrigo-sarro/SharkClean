# %%
import pandas as pd
import re
import numpy as np
import matplotlib

# %%
sharkfile = pd.read_csv('D:/Shark Clean/attacks.csv', encoding = 'latin1', sep = ',')

# %%
sharkfile
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharkfile = sharkfile.drop(columns = ['href','Case Number.2', 'Unnamed: 22','Unnamed: 23','Case Number.1'])

# %%
sharkfile
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharkfile_clean = sharkfile.dropna(axis = 0,subset = sharkfile.drop(['Case Number', 'original order'], axis = 1).columns, how = 'all')

# %%
sharkfile_clean
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharkfile_clean.isnull().sum()
# Out:
# Case Number                  1
# Date                         0
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href formula                 1
# original order               0
# dtype: int64

# %%
sharkfile_clean['Time'].isnull().sum()
# Out:
# 3354

# %%
shark_time_clean = sharkfile_clean['Time'].dropna(axis=0)

# %%
sharkclean = sharkfile_clean.dropna(subset = ['Time'], axis=0)

# %%
sharkclean
# Out:
#        Case Number         Date    Year          Type Country        Area  \
# 0       2018.06.25  25-Jun-2018  2018.0       Boating     USA  California
# 1       2018.06.18  18-Jun-2018  2018.0    Unprovoked     USA     Georgia
# 2       2018.06.09  09-Jun-2018  2018.0       Invalid     USA      Hawaii
# 6     2018.06.03.a  03-Jun-2018  2018.0    Unprovoked  BRAZIL  Pernambuco
# 8     2018.05.26.b  26-May-2018  2018.0    Unprovoked     USA     Florida
# ...            ...          ...     ...           ...     ...         ...
# 6241       ND.0065        1960s     0.0    Unprovoked    IRAQ      Basrah
# 6242       ND.0064        1960s     0.0    Unprovoked    IRAQ      Basrah
# 6243       ND.0063        1960s     0.0    Unprovoked    IRAQ      Basrah
# 6259       ND.0044    1941-1945     0.0  Sea Disaster     NaN         NaN
# 6265       ND.0038    1941-1942     0.0    Unprovoked    IRAQ      Basrah
#
#                                          Location  \
# ...

# %%
shark_time_clean
# Out:
# 0                18h00
# 1        14h00  -15h00
# 2                07h45
# 6       Late afternoon
# 8                17h00
#              ...
# 6241         Afternoon
# 6242         Afternoon
# 6243         Afternoon
# 6259    Late afternoon
# 6265         Afternoon
# Name: Time, Length: 2948, dtype: object

# %%
def horariocerto(o):
    o = re.sub('.*[Nn]ight.*', 'Night', o)
    o = re.sub('.*[Dd]usk.*', 'Night', o)
    o = re.sub('.*[Mm]orning.*', 'Morning', o)
    o = re.sub('Evening', 'Afternoon',o)
    o = re.sub('.*[Aa]fternoon.*', 'Afternoon', o)
    o = re.sub('[2][0-3]\w\d+', 'Night', o)
    o = re.sub('[1][9]\w\d+', 'Night', o)
    o = re.sub('[1][2-8]\w\d+' , 'Afternoon', o)
    o = re.sub('[0 ][0-9]\w\d+' , 'Morning', o)
    o = re.sub('[1][0-2]\w\d*' , 'Morning', o)
    o = re.sub('[1][0-2]\w\d*' , 'Morning', o)
    o = re.sub('.*[Aa][. -][mM].*' , 'Morning', o)
    o = re.sub('.*[pP][. -][mM].*' , 'Afternoon', o)
    o = re.sub('.*[Mm]idday.*' , 'Morning', o)
    return o

# %%
shark_time = shark_time_clean.apply(horariocerto)

# %%
sharkclean['Time'] = sharkclean['Time'].apply(horariocerto)
# Out:
# <ipython-input-43-fa45be4b851a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharkclean['Time'] = sharkclean['Time'].apply(horariocerto)

# %%
shark_time.value_counts()
# Out:
# Afternoon                         1709
# Morning                            949
# Night                              189
# --                                   5
# Morning - Morning                    4
#                                   ...
# Ship aban-doned at Morning           1
# X                                    1
# 2 hours after Opperman               1
# 30 minutes after Night.07.08.a       1
# Just before sundown                  1
# Name: Time, Length: 71, dtype: int64

# %%
pd.options.display.max_rows = 63

# %%
sharkclean['Time'].value_counts()[sharkclean['Time'].value_counts() > 5].index
# Out:
# Index(['Afternoon', 'Morning', 'Night'], dtype='object')

# %%
sharkclean = sharkclean.loc[sharkclean['Time'].isin(sharkclean['Time'].value_counts()[sharkclean['Time'].value_counts() > 5].index)]

# %%
sharkclean['Time'].value_counts(normalize = True)*100
# Out:
# Afternoon    60.028100
# Morning      33.333333
# Night         6.638567
# Name: Time, dtype: float64

# %%
sharkclean['Time'].value_counts().plot.pie(labels = ['Afternoon 60%','Morning 33%','Night 6%'])
# Out:
# <AxesSubplot:ylabel='Time'>
